# %% [markdown]
# <a href="https://colab.research.google.com/github/Gracyvinayagamoorthy/Data-Analyst-Task-1/blob/main/Choco_sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Chocolate Sales.csv")

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
df['Amount'] = df['Amount'].replace('[\$,]', '', regex=True).astype(float)

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date   Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   5320.0
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   7896.0
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   4501.0
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  12726.0
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  13685.0
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
# Out:
# <ipython-input-9-0acb60aa0d69>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# %%
df.isnull().sum()
# Out:
# Sales Person     0
# Country          0
# Product          0
# Date             0
# Amount           0
# Boxes Shipped    0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df['Sales Person'] = df['Sales Person'].str.lower().str.strip()
df['Country'] = df['Country'].str.lower().str.strip()
df['Product'] = df['Product'].str.lower().str.strip()

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.to_csv('cleaned_chocolate_sales.csv', index=False)

# %% [markdown]
# ### Data Cleaning Summary

# %% [markdown]
# I removed dollar signs ($) and commas (,) from the Amount column, and then converted it into float for numerical analysis,Converted the Date column to proper datetime format so I can use it for time-based analysis later.
#
# Checked for missing values and handled them accordingly – either filled with defaults or dropped if unnecessary also Removed any duplicate records to ensure accuracy in the dataset.
#
# Renamed the column headers to snake_case (like sales_person, boxes_shipped, etc.) to follow a cleaner and more readable format and Finally, saved the cleaned data into a new file as✅ cleaned_chocolate_sales.csv
